# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanford-Lab/satellite_cnns/blob/main/1_dd_kenya_apache.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# Kenya project prediction notebook using an [Apache-Beam workflow](https://colab.research.google.com/github/GoogleCloudPlatform/python-docs-samples/blob/mai[…]ple-and-planet-ai/land-cover-classification/README.ipynb). And
#
#
#
#
# https://colab.research.google.com/github/GoogleCloudPlatform/python-docs-samples/blob/main/people-and-planet-ai/land-cover-classification/cloud-tensorflow.ipynb#scrollTo=D8Kwmqa8CpQV
#
#
#
# ---
#
#
# To Do:
#
#
# *   **FIX** misaligned tensor (under Train Model)
# *   Check  `target` variable
# *   Add block descriptions
# *   Add descriptions

# %% [markdown]
# # Initial Software and Libraries

# %%
#After running this cell, restart your kernel and run it again to properly import geemap
#import subprocess

# try:
#     import geemap
# except ImportError:
#     print('Installing geemap ...')
    
#     !pip install earthengine-api

# %% [markdown]
# ## Install the proper modules and then **restarts runtime**
#
#
# For standardization, we're pulling requirements directly from the git repo from [GoogleCloudPlatform](https://github.com/GoogleCloudPlatform)

# %%
repo_url = "https://raw.githubusercontent.com/GoogleCloudPlatform/python-docs-samples/main/people-and-planet-ai/land-cover-classification"

# !wget --quiet {repo_url}/requirements.txt

# %%
# !pip install --quiet --upgrade pip

# %%
# Install the dependencies.
# !pip install --quiet -r requirements.txt

# Restart the runtime by ending the process.
exit()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 24.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.8/245.8 kB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 21.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 73.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.5/140.5 kB 13.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 14.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 47.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.5/515.5 kB 35.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.6/327.6 kB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.1/288.1 kB 22.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.2/134.2 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.7/268.7 kB 23.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.4/185.4 kB 18.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.2/148.2 kB 14.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 kB 20.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.3/444.3 kB 29.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.8/276.8 kB 20.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 51.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 81.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 79.5 MB/s eta 0:00:00
#   Building wheel for earthengine-api (setup.py) ... done
#   Building wheel for crcmod (setup.py) ... done
#   Building wheel for dill (setup.py) ... done
#   Building wheel for google-apitools (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done

# %% [markdown]
# **RESTART RUNTIME** (Runtime<Restart)

# %% [markdown]
# ## Google Setup
#
# Input your Google Cloud project id (might be different from name)

# %%
from __future__ import annotations

import os
from google.colab import auth

auth.authenticate_user()

# Please fill in these values.
project = "ls-test-3-24" #@param {type:"string"}

# Quick input validations.
assert project, "ERROR: Make sure you are providing a valid Google Cloud project ID"

# Set GOOGLE_CLOUD_PROJECT for google.auth.default().
os.environ['GOOGLE_CLOUD_PROJECT'] = project

# Set the gcloud project for other gcloud commands.
# !gcloud config set project {project}
# Out:
# Updated property [core/project].

# %%
import ee
import google.auth

credentials, _ = google.auth.default()
ee.Initialize(
    credentials.with_quota_project(None),
    project=project,
    opt_url="https://earthengine-highvolume.googleapis.com",
)

# %% [markdown]
# ### Cloud Storage Setup
#
# You must have write access to a bucket to run this demo!  To run it read-only, use the demo bucket below, but note that writes to this bucket will not work.

# %%
# INSERT YOUR BUCKET HERE:
bucket = 'kenya-bucket'  #@param {type:"string"}
location = "us-central1" #@param {type:"string"}

# %% [markdown]
# ## Other Configurations

# %%
# Defining neccessary functions

def mask_clouds_landsat(image: ee.Image) -> ee.Image:
  # Bits 3 and 5 are cloud shadow and cloud, respectively
  cloudShadowBitMask = (1 << 3) # 1000 in base 2
  cloudsBitMask = (1 << 5) # 100000 in base 2

  # Get the pixel QA band
  qa = image.select('pixel_qa')

  #Both flags should be set to zero, indicating clear conditions
  mask = qa.bitwiseAnd(cloudShadowBitMask).eq(0).bitwiseAnd(qa.bitwiseAnd(cloudsBitMask).eq(0))

  # Mask image with clouds and shadows
  return image.updateMask(mask)


def get_input_image(year: int, default_value: float = 1000.0) -> ee.Image:
  return(
      ee.ImageCollection("LANDSAT/LE07/C01/T1_SR")
      .filterDate(f'{year}-01-01', f'{year}-12-31')
      .map(mask_clouds_landsat)
      .select("B.*")
      .median()
      .unmask(default_value)
      .float()
  )


def cloudMaskL457(image): 
  qa = image.select('pixel_qa')
  # If the cloud bit (5) is set and the cloud confidence (7) is high
  # or the cloud shadow bit is set (3), then it's a bad pixel.
  cloud = qa.bitwiseAnd(1 << 5).And(qa.bitwiseAnd(1 << 7)).Or(qa.bitwiseAnd(1 << 3))
  # Remove edge pixels that don't occur in all bands
  mask2 = image.mask().reduce(ee.Reducer.min())
  return image.updateMask(cloud.Not()).updateMask(mask2)

# %%
import tensorflow as tf
print("tf version: {}".format(tf.__version__))
import folium

opticalBands = ['B3','B2','B1'] #RGB
thermalBands = ['B4','B3'] #NIR

# Specify inputs (Landsat bands) to the model and the response variable.

BANDS = ['R', 'G', 'B', 'NDVI']
RESPONSE = 'target'

CENSUS_YR = '2009'  #@param {type:"string"}

#Download Kenya Data and create Raster of villages
census = ee.Image('projects/sanford-project-04a9/assets/Kenya/kenya_census_' + CENSUS_YR + '_rast')

# #Get Kenya Feature collection
kenya = ee.FeatureCollection("USDOS/LSIB_SIMPLE/2017").filter(ee.Filter.eq('country_na','Kenya')).set('ORIG_FID',0)

# Geometry selects from all of Kenya
image = ee.ImageCollection("LANDSAT/LE07/C01/T1_SR").filterDate(CENSUS_YR + '-01-01', CENSUS_YR + '-12-31')\
            .map(cloudMaskL457)\
            .median()\
            .clip(kenya.geometry().buffer(10000))\
            
image_ndvi = image.normalizedDifference(thermalBands).rename(['NDVI'])
image_rgb = image.select(opticalBands).rename(['R','G','B']) 
image = image_rgb.addBands(image_ndvi)

target = census.select('b1').rename("target")
# Out:
# tf version: 2.11.0

# %%
print(image.bandNames().getInfo())
# Out:
# ['R', 'G', 'B', 'NDVI']

# %%
print(target.getInfo())
# Out:
# {'type': 'Image', 'bands': [{'id': 'target', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [29676, 37426], 'crs': 'EPSG:32737', 'crs_transform': [30, 0, -67088.3816999998, 0, -30, 10605534.1865]}], 'version': 1667329384912485, 'id': 'projects/sanford-project-04a9/assets/Kenya/kenya_census_2009_rast', 'properties': {'system:footprint': {'type': 'LinearRing', 'coordinates': [[33.899676480467825, -3.712381049241454], [33.89351506051154, -4.661100260662413], [37.900507946594495, -4.678851591182628], [41.91295489440698, -4.673655155923738], [41.90670508116313, -2.7713382186237463], [41.90334965079649, -0.23517632895609153], [41.90379440308304, 1.032915523138402], [41.90893442251192, 3.5690508582490628], [41.916536101341734, 5.471324856577909], [37.899154212658445, 5.477412980838261], [33.88725958188004, 5.456615444350572], [33.902203461985884, 3.2433133930818694], [33.90731169057764, 1.978657066626101], [33.910330837555634, 0.08162750001535511], [33.9092551841757, -1.1830638177104547], [33.90570657939833, -2.447739075555494], [33.899676480467825, -3.712381049241454]]}, 'system:asset_size': 20024629}}

# %%
import folium

def add_ee_layer(self, ee_image_object, vis_params, name):
  map_id_dict = ee.Image(ee_image_object).getMapId(vis_params)
  folium.raster_layers.TileLayer(
      tiles=map_id_dict['tile_fetcher'].url_format,
      attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
      name=name,
      overlay=True,
      control=True
  ).add_to(self)

folium.Map.add_ee_layer = add_ee_layer

# %%
i_map = folium.Map(location=[0, 37], zoom_start = 6)

i_map.add_ee_layer(target, None, 'census map')
display(i_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9faf7c31bf5c9dfd7422300626d7cb14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9faf7c31bf5c9dfd7422300626d7cb14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9faf7c31bf5c9dfd7422300626d7cb14 = L.map(
#                 &quot;map_9faf7c31bf5c9dfd7422300626d7cb14&quot;,
#                 {
#                     center: [0.0, 37.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_825d0e49b1937ea9fc28bbc109d0dc16 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9faf7c31bf5c9dfd7422300626d7cb14);
#
#
#             var tile_layer_0794793b1c7d0f1636bfbde7cca0411c = L.tileLayer(
#                 &quot;https://earthengine-highvolume.googleapis.com/v1alpha/projects/ls-test-3-24/maps/eb15fe1553500cfa19d8a5d765c6c9e5-3c71b24000f2d8b33bed522d9b17e74d/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9faf7c31bf5c9dfd7422300626d7cb14);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Census mask visualization
c_map = folium.Map(location=[0, 37], zoom_start = 6)
og_img = ee.ImageCollection("LANDSAT/LE07/C01/T1_SR").filterDate(CENSUS_YR + '-01-01', CENSUS_YR + '-12-31')\
              .map(cloudMaskL457)\
              .median()\
              .clip(kenya.geometry().buffer(10000))\

c_map.add_ee_layer(image, None, 'census mask map')
display(c_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cbce6f09a7b587193526d5b0d841cb8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cbce6f09a7b587193526d5b0d841cb8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cbce6f09a7b587193526d5b0d841cb8 = L.map(
#                 &quot;map_3cbce6f09a7b587193526d5b0d841cb8&quot;,
#                 {
#                     center: [0.0, 37.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd1b2292d449c9721b38c195d535a8ff = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3cbce6f09a7b587193526d5b0d841cb8);
#
#
#             var tile_layer_c6128568b4abf151819487d40eed073e = L.tileLayer(
#                 &quot;https://earthengine-highvolume.googleapis.com/v1alpha/projects/ls-test-3-24/maps/89d5bd2220fb013db5094be8e60c195d-99e24e6384f768b7c187e328f70ce3e4/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3cbce6f09a7b587193526d5b0d841cb8);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### View imagery
# Census target and LANDSAT7

# %%
# Census mask visualization
c_map = folium.Map(location=[0, 37], zoom_start = 6)

c_map.add_ee_layer(target, None, 'census target map')
display(c_map)

# %%
# Image mask visualization
mapid = image.getMapId({'bands': ['R', 'G', 'B'], 'min': 0, 'max': 3000})
map = folium.Map(location=[0, 37], zoom_start = 6)
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='median composite',
  ).add_to(map)
map.add_child(folium.LayerControl())
map
# Out:
# WARNING:googleapiclient.http:Sleeping 0.17 seconds before retry 1 of 5 for request: POST https://earthengine-highvolume.googleapis.com/v1alpha/projects/ls-test-3-24/maps?fields=name&alt=json, after 500
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2b8dbf915c46f6306cdd34b0baa2787 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2b8dbf915c46f6306cdd34b0baa2787&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2b8dbf915c46f6306cdd34b0baa2787 = L.map(
#                 &quot;map_f2b8dbf915c46f6306cdd34b0baa2787&quot;,
#                 {
#                     center: [0.0, 37.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85c27e155ebe9862c633de2ee5393111 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2b8dbf915c46f6306cdd34b0baa2787);
#
#
#             var tile_layer_6e2e262b2740e05a6fa29ed196822970 = L.tileLayer(
#                 &quot;https://earthengine-highvolume.googleapis.com/v1alpha/projects/ls-test-3-24/maps/b71329838ff1f65f037d2c196b39b6da-be365179b0f7f9839fc843985eee5e19/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Map Data \u0026copy; \u003ca href=\&quot;https://earthengine.google.com/\&quot;\u003eGoogle Earth Engine\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f2b8dbf915c46f6306cdd34b0baa2787);
#
#
#             var layer_control_cc6590522b9a2966e2ca7176644d1238 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_85c27e155ebe9862c633de2ee5393111,
#                 },
#                 overlays :  {
#                     &quot;median composite&quot; : tile_layer_6e2e262b2740e05a6fa29ed196822970,
#                 },
#             };
#             L.control.layers(
#                 layer_control_cc6590522b9a2966e2ca7176644d1238.base_layers,
#                 layer_control_cc6590522b9a2966e2ca7176644d1238.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_f2b8dbf915c46f6306cdd34b0baa2787);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Training

# %% [markdown]
# ## Sampling
#
# Currently using random sampling in the Kenyan geometry

# %%
from typing import Iterable

SAMPLE_SEED = 0
NUM_POINTS = 4

# seed: int, region = region: ee.Geometry, image = image: ee.Image, 
#    points_per_class = points_per_class: int, scale = scale: int
def sample_points(
   seed: int, region = None, image = None, num_points = None, scale = None
) -> Iterable[tuple[float, float]]:

    feature_collection = ee.FeatureCollection(image.geometry())
    points = feature_collection.randomPoints(image.geometry(), points = num_points,seed=seed)


    for point in points.toList(points.size()).getInfo():
      yield point["geometry"]["coordinates"]

# Kenya Region
region = kenya.geometry()
labels_image = target
for point in sample_points(SAMPLE_SEED, region, labels_image, num_points=NUM_POINTS, scale=1000):
  print(point)
# Out:
# [38.795573673803595, 1.1104279881486983]
# [41.79166552412254, 5.403461144688108]
# [41.0971379543607, -3.881343561013298]
# [41.13595469478783, 0.8537859018080317]

# %% [markdown]
# ## Get training examples

# %%
import io
import numpy as np
import requests
from google.api_core import exceptions, retry

@retry.Retry(deadline=10 * 60)  # seconds
def get_patch(image: ee.Image, lonlat: tuple[float, float], patch_size: int, scale: int) -> np.ndarray:
    point = ee.Geometry.Point(lonlat)
    url = image.getDownloadURL({
        "region": point.buffer(scale * patch_size / 2, 1).bounds(1),
        "dimensions": [patch_size, patch_size],
        "format": "NPY",
    })

    # If we get "429: Too Many Requests" errors, it's safe to retry the request.
    # The Retry library only works with `google.api_core` exceptions.
    response = requests.get(url)
    if response.status_code == 429:
        raise exceptions.TooManyRequests(response.text)

    # Still raise any other exceptions to make sure we got valid data.
    response.raise_for_status()
    return np.load(io.BytesIO(response.content), allow_pickle=True)

# %% [markdown]
# Helper functions to get the inputs and labels patches of pixels. We'll use this function both for getting inputs for the training examples, and for predictions later on.

# %%
from numpy.lib.recfunctions import structured_to_unstructured

def get_input_patch(image, year: int, lonlat: tuple[float, float], patch_size: int) -> np.ndarray:
    patch = get_patch(image, lonlat, patch_size, scale=30)
    return structured_to_unstructured(patch)

def get_label_patch(image, lonlat: tuple[float, float], patch_size: int) -> np.ndarray:

    patch = get_patch(image, lonlat, patch_size, scale=30)
    return structured_to_unstructured(patch)

# %%
# Note: Changed get_input_patch(image, 2020, lonlat, patch_size) to be CENSUS_YR
def get_training_example(lonlat, image = None, labels = None, patch_size = 128):
    return (
        get_input_patch(image, CENSUS_YR, lonlat, patch_size),
        get_label_patch(labels, lonlat, patch_size),
    )

point = [38.795573673803595, 1.1104279881486983] # this point comes from sample_points[0] return
(inputs, labels) = get_training_example(point, image = image, labels = target, patch_size = 128)
print(f"inputs : {inputs.dtype} {inputs.shape}")
print(f"labels : {labels.dtype} {labels.shape}")
# Out:
# inputs : float64 (128, 128, 4)
# labels : float32 (128, 128, 1)

# %%
# Test that we have inputs (shouldn't be 0)
np.amax(inputs)
# Out:
# 2242.0

# %% [markdown]
# Visualize

# %%
# Grab visuals
inputs_visual = inputs[:,:, :3]
inputs_visual = inputs_visual/np.amax(inputs_visual)

# %%
import matplotlib.pyplot as plt

# Show visuals
plt.imshow(inputs_visual)
plt.show()

# %%
# Currently 0
np.amax(labels)
plt.imshow(labels)
plt.show()

# %% [markdown]
# Visualizing target (again)

# %%
# Showing correct(?) output
import folium

mapid = target.getMapId({'min': 0, 'max': 1})
map = folium.Map(location=[0, 37], zoom_start = 6)
folium.TileLayer(
    tiles=mapid['tile_fetcher'].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
    overlay=True,
    name='target variable',
  ).add_to(map)
map.add_child(folium.LayerControl())
map

# %% [markdown]
# Visualizing image (again...)

# %%
#Showing correct output

import folium

vis_params = {
  "min": 0,
  "max": 3000,
  "bands": ["R", "G", "B"],
}
folium.Map(
    location=(0,37),
    zoom_start=6,
    tiles=image.getMapId(vis_params)["tile_fetcher"].url_format,
    attr='Map Data &copy; <a href="https://earthengine.google.com/">Google Earth Engine</a>',
)

# %% [markdown]
# ## Apache-beam

# %% [markdown]
# Serialize to TFRecords

# %%
import tensorflow as tf

def serialize(inputs: np.ndarray, labels: np.ndarray) -> bytes:
    features = {
        name: tf.train.Feature(
            bytes_list=tf.train.BytesList(value=[tf.io.serialize_tensor(data).numpy()])
        )
        for name, data in {"inputs": inputs, "labels": labels}.items()
    }
    example = tf.train.Example(features=tf.train.Features(feature=features))
    return example.SerializeToString()

serialized = serialize(inputs, labels)
print(f"serialized: {len(serialized)} bytes")
# Out:
# serialized: 589920 bytes

# %% [markdown]
# ### Creating Dataset

# %%
# Now let's get the code from GitHub and navigate to the sample.
# !git clone https://github.com/GoogleCloudPlatform/python-docs-samples.git
# %cd python-docs-samples/people-and-planet-ai/land-cover-classification
# Out:
# Cloning into 'python-docs-samples'...
# remote: Enumerating objects: 92767, done.
# remote: Counting objects: 100% (276/276), done.
# remote: Compressing objects: 100% (227/227), done.
# remote: Total 92767 (delta 117), reused 154 (delta 37), pack-reused 92491
# Receiving objects: 100% (92767/92767), 198.05 MiB | 23.08 MiB/s, done.
# Resolving deltas: 100% (55003/55003), done.
# Updating files: 100% (4323/4323), done.
# /content/python-docs-samples/people-and-planet-ai/land-cover-classification

# %%
from create_dataset import serialize_tensorflow
inputs = inputs_visual
serialized = serialize_tensorflow(inputs, labels)
print(f"serialized: {len(serialized)} bytes")
# Out:
# serialized: 458848 bytes

# %%
# Globals
PATCH_SIZE = 128
MAX_REQUESTS = 20
data_path=f"gs://{bucket}/land-cover/data"

# %%
def run_tensorflow(
    data_path: str,
    points_per_class: int = points_per_class,
    patch_size: int = PATCH_SIZE,
    max_requests: int = MAX_REQUESTS,
    beam_args: Optional[List[str]] = None,
) -> None:
    """Runs an Apache Beam pipeline to create a dataset.
    This fetches data from Earth Engine and creates a TFRecords dataset.
    We use `max_requests` to limit the number of concurrent requests to Earth Engine
    to avoid quota issues. You can request for an increas of quota if you need it.
    Args:
        data_path: Directory path to save the TFRecord files.
        points_per_class: Number of points to get for each classification.
        patch_size: Size in pixels of the surrounding square patch.
        max_requests: Limit the number of concurrent requests to Earth Engine.
        polygons: List of polygons to pick points from.
        beam_args: Apache Beam command line arguments to parse as pipeline options.
    """
    # Equally divide the number of points by the number of concurrent requests.
    num_points = max(int(points_per_class / max_requests), 1)

    beam_options = PipelineOptions(
        beam_args,
        save_main_session=True,
        setup_file="./setup.py",
        max_num_workers=max_requests,  # distributed runners
        direct_num_workers=max(max_requests, 20),  # direct runner
        disk_size_gb=50,
    )
    with beam.Pipeline() as pipeline:
        (
            pipeline
            | "🌱 Make seeds" >> beam.Create([0])
            | "🛰 Sample points" >> beam.FlatMap(sample_points, region=region, image=labels_image, num_points=NUM_POINTS, scale=1000)
            | "📖 Get examples" >> beam.Map(get_training_example, image=image, labels=target, patch_size=PATCH_SIZE)
            | "✍🏽 Serialize" >> beam.MapTuple(serialize_tensorflow)
            | "📚 Write TFRecords" >> beam.io.WriteToTFRecord(
                f"{data_path}/part", file_name_suffix=".tfrecord.gz"
            )
        )

# %%
DATA_PATH = f"gs://{bucket}/land-cover/data"

# %% [markdown]
# Run the adapted Apache pipeline:

# %%
run_tensorflow(data_path=DATA_PATH)
# Out:
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d

# %%
# Let's take a look at the dataset files.
# !ls -lh data
# Out:
# total 356K
# -rw-r--r-- 1 root root 356K Apr 13 23:57 part-00000-of-00001.tfrecord.gz

# %% [markdown]
# Check wd, attach dataset, check dataset

# %%
import os 
current_dir = os.getcwd()

# Print current working directory
print("Current working directory:", current_dir)
# Out:
# Current working directory: /content/python-docs-samples/people-and-planet-ai/land-cover-classification

# %%
FILE_PATH = 'data/part-00000-of-00001.tfrecord.gz'
dataset = tf.data.TFRecordDataset(FILE_PATH, compression_type='GZIP')

print(dataset)
# Out:
# <TFRecordDatasetV2 element_spec=TensorSpec(shape=(), dtype=tf.string, name=None)>

# %%
for y  in dataset.take(2):
  #print("inputs:", x.dtype.name, x.shape)
  print("labels: {} {}".format(y.dtype.name, y.shape))
# Out:
# labels: string ()
# labels: string ()

# %% [markdown]
# Next use a distributed runner to run on a larger dataset (~20 min)

# %%
points_per_class = 100

# !python create_dataset.py "tensorflow" \
  --data-path="gs://{bucket}/land-cover/data" \
  --points-per-class="{points_per_class}" \
  --runner="DataflowRunner" \
  --project="{project}" \
  --region="{location}" \
  --temp_location="gs://{bucket}/land-cover/temp"
# Out:
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "list[list[tuple[float, float]]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "Iterable[tuple[float, float]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "list[list[tuple[float, float]]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "Iterable[tuple[float, float]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "list[list[tuple[float, float]]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "Iterable[tuple[float, float]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "tuple[float, float]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "Iterable[tuple[np.ndarray, np.ndarray]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "tuple[float, float]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "Iterable[tuple[np.ndarray, np.ndarray]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "tuple[float, float]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "int"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "Iterable[tuple[np.ndarray, np.ndarray]]"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "np.ndarray"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "np.ndarray"
# INFO:apache_beam.typehints.native_type_compatibility:Converting string literal type hint to Any: "bytes"
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', 'setup.py', 'sdist', '--dist-dir', '/tmp/tmpn1ji9r2d']
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) should be supplied
#
# INFO:apache_beam.runners.portability.stager:Downloading source distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', '-m', 'pip', 'download', '--dest', '/tmp/tmpn1ji9r2d', 'apache-beam==2.46.0', '--no-deps', '--no-binary', ':all:']
# INFO:apache_beam.runners.portability.stager:Staging SDK sources from PyPI: dataflow_python_sdk.tar
# INFO:apache_beam.runners.portability.stager:Downloading binary distribution of the SDK from PyPi
# INFO:apache_beam.runners.portability.stager:Executing command: ['/usr/bin/python3', '-m', 'pip', 'download', '--dest', '/tmp/tmpn1ji9r2d', 'apache-beam==2.46.0', '--no-deps', '--only-binary', ':all:', '--python-version', '39', '--implementation', 'cp', '--abi', 'cp39', '--platform', 'manylinux2014_x86_64']
# INFO:apache_beam.runners.portability.stager:Staging binary distribution of the SDK from PyPI: apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# INFO:root:Default Python SDK image for environment is apache/beam_python3.9_sdk:2.46.0
# INFO:root:Using provided Python SDK container image: gcr.io/cloud-dataflow/v1beta3/python39:2.46.0
# INFO:root:Python SDK container image set to "gcr.io/cloud-dataflow/v1beta3/python39:2.46.0" for Docker environment
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function pack_combiners at 0x7f9041758820> ====================
# INFO:apache_beam.runners.portability.fn_api_runner.translations:==================== <function sort_stages at 0x7f9041759040> ====================
# INFO:apache_beam.runners.dataflow.internal.apiclient:Defaulting to the temp_location as staging_location: gs://kenya-bucket/land-cover/temp
# INFO:apache_beam.internal.gcp.auth:Setting socket default timeout to 60 seconds.
# INFO:apache_beam.internal.gcp.auth:socket default timeout is 60.0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/pickled_main_session...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/pickled_main_session in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/dataflow_python_sdk.tar...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/dataflow_python_sdk.tar in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/workflow.tar.gz...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/workflow.tar.gz in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/apache_beam-2.46.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl in 4 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Starting GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/pipeline.pb...
# INFO:apache_beam.runners.dataflow.internal.apiclient:Completed GCS upload to gs://kenya-bucket/land-cover/temp/beamapp-root-0414002002-972354-5g45jswb.1681431602.972763/pipeline.pb in 0 seconds.
# INFO:apache_beam.runners.dataflow.internal.apiclient:Create job: <Job
#  clientRequestId: '20230414002002974336-6451'
#  createTime: '2023-04-14T00:20:10.232438Z'
#  currentStateTime: '1970-01-01T00:00:00Z'
#  id: '2023-04-13_17_20_09-7587646848022066060'
#  location: 'us-central1'
#  name: 'beamapp-root-0414002002-972354-5g45jswb'
#  projectId: 'ls-test-3-24'
#  stageStates: []
#  startTime: '2023-04-14T00:20:10.232438Z'
#  steps: []
#  tempFiles: []
#  type: TypeValueValuesEnum(JOB_TYPE_BATCH, 1)>
# INFO:apache_beam.runners.dataflow.internal.apiclient:Created job with id: [2023-04-13_17_20_09-7587646848022066060]
# INFO:apache_beam.runners.dataflow.internal.apiclient:Submitted job: 2023-04-13_17_20_09-7587646848022066060
# INFO:apache_beam.runners.dataflow.internal.apiclient:To access the Dataflow monitoring console, please navigate to https://console.cloud.google.com/dataflow/jobs/us-central1/2023-04-13_17_20_09-7587646848022066060?project=ls-test-3-24
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-04-13_17_20_09-7587646848022066060 is in state JOB_STATE_PENDING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:09.573Z: JOB_MESSAGE_BASIC: Dataflow Runner V2 auto-enabled. Use --experiments=disable_runner_v2 to opt out.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:11.747Z: JOB_MESSAGE_BASIC: The pipeline is using shuffle service with a (boot) persistent disk size / type other than the default. If that configuration was intended solely to speed up the non-service shuffle, consider removing it to reduce costs as those disks are unused by the shuffle service.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:12.101Z: JOB_MESSAGE_DETAILED: Autoscaling is enabled for job 2023-04-13_17_20_09-7587646848022066060. The number of workers will be between 1 and 20.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:12.137Z: JOB_MESSAGE_DETAILED: Autoscaling was automatically enabled for job 2023-04-13_17_20_09-7587646848022066060.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.014Z: JOB_MESSAGE_BASIC: Worker configuration: n1-standard-1 in us-central1-b.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.604Z: JOB_MESSAGE_DETAILED: Expanding SplittableParDo operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.650Z: JOB_MESSAGE_DETAILED: Expanding CollectionToSingleton operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.735Z: JOB_MESSAGE_DETAILED: Expanding CoGroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.768Z: JOB_MESSAGE_DEBUG: Combiner lifting skipped for step 📚 Write TFRecords/Write/WriteImpl/GroupByKey: GroupByKey not followed by a combiner.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.797Z: JOB_MESSAGE_DEBUG: Combiner lifting skipped for step 🃏 Reshuffle/ReshufflePerKey/GroupByKey: GroupByKey not followed by a combiner.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.826Z: JOB_MESSAGE_DEBUG: Combiner lifting skipped for step 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey: GroupByKey not followed by a combiner.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.857Z: JOB_MESSAGE_DETAILED: Expanding GroupByKey operations into optimizable parts.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.885Z: JOB_MESSAGE_DEBUG: Annotating graph with Autotuner information.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.927Z: JOB_MESSAGE_DETAILED: Fusing adjacent ParDo, Read, Write, and Flatten operations
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.959Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/InitializeWrite into 📚 Write TFRecords/Write/WriteImpl/DoOnce/Map(decode)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:14.990Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/FlatMap(<lambda at core.py:3507>) into 🌱 Make seeds/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.023Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/AddRandomKeys into 🌱 Make seeds/FlatMap(<lambda at core.py:3507>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.057Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/Map(reify_timestamps) into 🌱 Make seeds/MaybeReshuffle/Reshuffle/AddRandomKeys
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.081Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Reify into 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/Map(reify_timestamps)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.114Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Write into 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Reify
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.146Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow into 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Read
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.166Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps) into 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.199Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/MaybeReshuffle/Reshuffle/RemoveRandomKeys into 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.231Z: JOB_MESSAGE_DETAILED: Fusing consumer 🌱 Make seeds/Map(decode) into 🌱 Make seeds/MaybeReshuffle/Reshuffle/RemoveRandomKeys
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.276Z: JOB_MESSAGE_DETAILED: Fusing consumer 📌 Sample points into 🌱 Make seeds/Map(decode)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.318Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/AddRandomKeys into 📌 Sample points
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.360Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/ReshufflePerKey/Map(reify_timestamps) into 🃏 Reshuffle/AddRandomKeys
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.392Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Reify into 🃏 Reshuffle/ReshufflePerKey/Map(reify_timestamps)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.424Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Write into 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Reify
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.458Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow into 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Read
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.490Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps) into 🃏 Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.522Z: JOB_MESSAGE_DETAILED: Fusing consumer 🃏 Reshuffle/RemoveRandomKeys into 🃏 Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.554Z: JOB_MESSAGE_DETAILED: Fusing consumer 📑 Get examples into 🃏 Reshuffle/RemoveRandomKeys
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.587Z: JOB_MESSAGE_DETAILED: Fusing consumer ✍🏽 Serialize into 📑 Get examples
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.620Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/WindowInto(WindowIntoFn) into ✍🏽 Serialize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.652Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>) into 📚 Write TFRecords/Write/WriteImpl/DoOnce/Impulse
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.683Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/DoOnce/Map(decode) into 📚 Write TFRecords/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.715Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/WriteBundles into 📚 Write TFRecords/Write/WriteImpl/WindowInto(WindowIntoFn)
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.748Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/Pair into 📚 Write TFRecords/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.780Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Write into 📚 Write TFRecords/Write/WriteImpl/Pair
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.802Z: JOB_MESSAGE_DETAILED: Fusing consumer 📚 Write TFRecords/Write/WriteImpl/Extract into 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Read
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.849Z: JOB_MESSAGE_DEBUG: Workflow config is missing a default resource spec.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.878Z: JOB_MESSAGE_DEBUG: Adding StepResource setup and teardown to workflow graph.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.910Z: JOB_MESSAGE_DEBUG: Adding workflow start and stop steps.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:15.944Z: JOB_MESSAGE_DEBUG: Assigning stage ids.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.073Z: JOB_MESSAGE_DEBUG: Executing wait step start32
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.139Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/DoOnce/Impulse+📚 Write TFRecords/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+📚 Write TFRecords/Write/WriteImpl/DoOnce/Map(decode)+📚 Write TFRecords/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.161Z: JOB_MESSAGE_BASIC: Executing operation 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.184Z: JOB_MESSAGE_DEBUG: Starting worker pool setup.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.216Z: JOB_MESSAGE_BASIC: Starting 1 workers in us-central1-b...
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.593Z: JOB_MESSAGE_BASIC: Finished operation 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.654Z: JOB_MESSAGE_DEBUG: Value "🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Session" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:20:16.720Z: JOB_MESSAGE_BASIC: Executing operation 🌱 Make seeds/Impulse+🌱 Make seeds/FlatMap(<lambda at core.py:3507>)+🌱 Make seeds/MaybeReshuffle/Reshuffle/AddRandomKeys+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/Map(reify_timestamps)+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Reify+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-04-13_17_20_09-7587646848022066060 is in state JOB_STATE_RUNNING
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:22:31.339Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 1 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:23:07.675Z: JOB_MESSAGE_DETAILED: Workers have started successfully.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:10.552Z: JOB_MESSAGE_DETAILED: All workers have finished the startup processes and began to receive work requests.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.025Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/DoOnce/Impulse+📚 Write TFRecords/Write/WriteImpl/DoOnce/FlatMap(<lambda at core.py:3507>)+📚 Write TFRecords/Write/WriteImpl/DoOnce/Map(decode)+📚 Write TFRecords/Write/WriteImpl/InitializeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.093Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/DoOnce/Map(decode).None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.125Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/InitializeWrite.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.180Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.201Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/WriteBundles/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.222Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/PreFinalize/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.240Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.246Z: JOB_MESSAGE_BASIC: Finished operation 🌱 Make seeds/Impulse+🌱 Make seeds/FlatMap(<lambda at core.py:3507>)+🌱 Make seeds/MaybeReshuffle/Reshuffle/AddRandomKeys+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/Map(reify_timestamps)+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Reify+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.266Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/WriteBundles/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/WriteBundles
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.278Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.282Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/PreFinalize/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.300Z: JOB_MESSAGE_BASIC: Executing operation 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.331Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/WriteBundles/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/WriteBundles.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.354Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/PreFinalize/View-python_side_input0-📚 Write TFRecords/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.394Z: JOB_MESSAGE_BASIC: Finished operation 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.451Z: JOB_MESSAGE_BASIC: Executing operation 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.571Z: JOB_MESSAGE_BASIC: Finished operation 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.627Z: JOB_MESSAGE_DEBUG: Value "🃏 Reshuffle/ReshufflePerKey/GroupByKey/Session" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:12.688Z: JOB_MESSAGE_BASIC: Executing operation 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Read+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps)+🌱 Make seeds/MaybeReshuffle/Reshuffle/RemoveRandomKeys+🌱 Make seeds/Map(decode)+📌 Sample points+🃏 Reshuffle/AddRandomKeys+🃏 Reshuffle/ReshufflePerKey/Map(reify_timestamps)+🃏 Reshuffle/ReshufflePerKey/GroupByKey/Reify+🃏 Reshuffle/ReshufflePerKey/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:22.228Z: JOB_MESSAGE_BASIC: Finished operation 🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/Read+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow+🌱 Make seeds/MaybeReshuffle/Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps)+🌱 Make seeds/MaybeReshuffle/Reshuffle/RemoveRandomKeys+🌱 Make seeds/Map(decode)+📌 Sample points+🃏 Reshuffle/AddRandomKeys+🃏 Reshuffle/ReshufflePerKey/Map(reify_timestamps)+🃏 Reshuffle/ReshufflePerKey/GroupByKey/Reify+🃏 Reshuffle/ReshufflePerKey/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:22.279Z: JOB_MESSAGE_BASIC: Executing operation 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:22.787Z: JOB_MESSAGE_BASIC: Finished operation 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:22.852Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:22.976Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Create
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:23.029Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/GroupByKey/Session" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:27:23.087Z: JOB_MESSAGE_BASIC: Executing operation 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Read+🃏 Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow+🃏 Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps)+🃏 Reshuffle/RemoveRandomKeys+📑 Get examples+✍🏽 Serialize+📚 Write TFRecords/Write/WriteImpl/WindowInto(WindowIntoFn)+📚 Write TFRecords/Write/WriteImpl/WriteBundles+📚 Write TFRecords/Write/WriteImpl/Pair+📚 Write TFRecords/Write/WriteImpl/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:28:56.705Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 3 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:28:56.731Z: JOB_MESSAGE_DETAILED: Autoscaling: Resized worker pool to 3, though goal was 7.  This could be a quota issue.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:29:01.512Z: JOB_MESSAGE_DETAILED: Autoscaling: Resizing worker pool from 1 to 7.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:29:06.673Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 7 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:29:58.189Z: JOB_MESSAGE_WARNING: Autoscaling: Unable to reach resize target in zone us-central1-b. QUOTA_EXCEEDED: Instance 'beamapp-root-0414002002-9-04131720-jz63-harness-07md' creation failed: Quota 'IN_USE_ADDRESSES' exceeded.  Limit: 8.0 in region us-central1.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:30:02.749Z: JOB_MESSAGE_DETAILED: Autoscaling: Resizing worker pool from 7 to 9.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:30:17.590Z: JOB_MESSAGE_DETAILED: Autoscaling: Raised the number of workers to 8 based on the rate of progress in the currently running stage(s).
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:30:17.620Z: JOB_MESSAGE_DETAILED: Autoscaling: Resized worker pool to 8, though goal was 9.  This could be a quota issue.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:37:51.891Z: JOB_MESSAGE_DETAILED: Autoscaling: Resizing worker pool from 9 to 10.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:56.927Z: JOB_MESSAGE_BASIC: Finished operation 🃏 Reshuffle/ReshufflePerKey/GroupByKey/Read+🃏 Reshuffle/ReshufflePerKey/GroupByKey/GroupByWindow+🃏 Reshuffle/ReshufflePerKey/FlatMap(restore_timestamps)+🃏 Reshuffle/RemoveRandomKeys+📑 Get examples+✍🏽 Serialize+📚 Write TFRecords/Write/WriteImpl/WindowInto(WindowIntoFn)+📚 Write TFRecords/Write/WriteImpl/WriteBundles+📚 Write TFRecords/Write/WriteImpl/Pair+📚 Write TFRecords/Write/WriteImpl/GroupByKey/Write
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:56.987Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:57.940Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Close
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:57.978Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Read+📚 Write TFRecords/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:58.980Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/GroupByKey/Read+📚 Write TFRecords/Write/WriteImpl/Extract
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.026Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/Extract.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.070Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input1-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.092Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/PreFinalize/View-python_side_input1-📚 Write TFRecords/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.113Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input1-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.134Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/PreFinalize/View-python_side_input1-📚 Write TFRecords/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.147Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input1-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.160Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/PreFinalize/View-python_side_input1-📚 Write TFRecords/Write/WriteImpl/PreFinalize.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:38:59.204Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:00.632Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/PreFinalize
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:00.670Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/PreFinalize.None" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:00.712Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input2-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:00.746Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input2-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:00.787Z: JOB_MESSAGE_DEBUG: Value "📚 Write TFRecords/Write/WriteImpl/FinalizeWrite/View-python_side_input2-📚 Write TFRecords/Write/WriteImpl/FinalizeWrite.out" materialized.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:00.832Z: JOB_MESSAGE_BASIC: Executing operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:02.302Z: JOB_MESSAGE_BASIC: Finished operation 📚 Write TFRecords/Write/WriteImpl/FinalizeWrite
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:02.348Z: JOB_MESSAGE_DEBUG: Executing success step success30
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:02.381Z: JOB_MESSAGE_DETAILED: Cleaning up.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:02.533Z: JOB_MESSAGE_DEBUG: Starting worker pool teardown.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:39:02.554Z: JOB_MESSAGE_BASIC: Stopping worker pool...
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:40:02.025Z: JOB_MESSAGE_DETAILED: Autoscaling: Resized worker pool from 8 to 0.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:40:02.057Z: JOB_MESSAGE_BASIC: Worker pool stopped.
# INFO:apache_beam.runners.dataflow.dataflow_runner:2023-04-14T00:40:02.078Z: JOB_MESSAGE_DEBUG: Tearing down pending resources...
# INFO:apache_beam.runners.dataflow.dataflow_runner:Job 2023-04-13_17_20_09-7587646848022066060 is in state JOB_STATE_DONE

# %%
print(target.getInfo())
# Out:
# {'type': 'Image', 'bands': [{'id': 'target', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [29676, 37426], 'crs': 'EPSG:32737', 'crs_transform': [30, 0, -67088.3816999998, 0, -30, 10605534.1865]}], 'version': 1667329384912485, 'id': 'projects/sanford-project-04a9/assets/Kenya/kenya_census_2009_rast', 'properties': {'system:footprint': {'type': 'LinearRing', 'coordinates': [[33.899676480467825, -3.712381049241454], [33.89351506051154, -4.661100260662413], [37.900507946594495, -4.678851591182628], [41.91295489440698, -4.673655155923738], [41.90670508116313, -2.7713382186237463], [41.90334965079649, -0.23517632895609153], [41.90379440308304, 1.032915523138402], [41.90893442251192, 3.5690508582490628], [41.916536101341734, 5.471324856577909], [37.899154212658445, 5.477412980838261], [33.88725958188004, 5.456615444350572], [33.902203461985884, 3.2433133930818694], [33.90731169057764, 1.978657066626101], [33.910330837555634, 0.08162750001535511], [33.9092551841757, -1.1830638177104547], [33.90570657939833, -2.447739075555494], [33.899676480467825, -3.712381049241454]]}, 'system:asset_size': 20024629}}

# %%
target.bandNames().getInfo()
# Out:
# ['target']

# %%
target = get_label_image(image)
#Visualize imagery
map_target = folium.Map(location=[0, 37], zoom_start = 6)
map_target.add_ee_layer(target, None, 'target')

display(map_target)

# %% [markdown]
# # Train Model

# %%
# Specify names locations for outputs in Cloud Storage. 
FOLDER = 'unet_11-17_128_tiles_kenya_r_g_b_ndvi_treatment'
TRAINING_BASE = 'training_patches'
EVAL_BASE = 'eval_patches'

# %%
# !pwd

# !cd ~
# !cd data
# !ls
# Out:
# /content/python-docs-samples/people-and-planet-ai/land-cover-classification
# cloud-tensorflow.ipynb			pretrained-model
# create_dataset.py			__pycache__
# data					README.ipynb
# e2e_test.py				README.md
# images					requirements-test.txt
# land-cover-change.ipynb			requirements.txt
# MANIFEST.in				serving
# noxfile_config.py			setup.py
# ppai_landcover_classification.egg-info	trainer
# predict_batch.py			visualize.py
# predict-locations.csv

# %%
from trainer.tf_model import read_dataset
import numpy as np
import matplotlib.pyplot as plt
data_path = f"gs://{bucket}/land-cover/data"
dataset = read_dataset(data_path)

for x, y in dataset.take(1):
  print("inputs:", x.dtype.name, x.shape)
  print("labels:", y.dtype.name, y.shape)
  for start_ind in range(13-3):
    inputs_visual = x[:,:, start_ind:start_ind+3]
    inputs_visual = inputs_visual/np.amax(inputs_visual)
    plt.imshow(inputs_visual)
    plt.show()
# Out:
# inputs: float32 (128, 128, 13)
# labels: float32 (128, 128, 9)

# %%
print(dataset.range(8))
# Out:
# <RangeDataset element_spec=TensorSpec(shape=(), dtype=tf.int64, name=None)>

# %%
import tensorflow as tf
tf.debugging.set_log_device_placement(True)
print(len(tf.config.list_physical_devices('GPU')))
# Out:
# 0

# %%
from trainer.tf_model import create_model, split_dataset

(train_dataset, test_dataset) = split_dataset(dataset)
model = create_model(dataset)

model.summary()
tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-161-b7338079dee3> in <cell line: 4>()
#       2
#       3 (train_dataset, test_dataset) = split_dataset(dataset)
# ----> 4 model = create_model(dataset)
#       5
#       6 model.summary()
#
# /content/python-docs-samples/people-and-planet-ai/land-cover-classification/trainer/tf_model.py in create_model(dataset, kernel_size)
#     123     # Adapt the preprocessing layers.
#     124     normalization = tf.keras.layers.Normalization()
# --> 125     normalization.adapt(dataset.map(lambda inputs, _: inputs))
#     126
#     127     # Define the Fully Convolutional Network.
#
# /usr/local/lib/python3.9/dist-packages/keras/layers/preprocessing/normalization.py in adapt(self, data, batch_size, steps)
#     284               argument is not supported with array inputs.
#     285         """
# --> 286         super().adapt(data, batch_size=batch_size, steps=steps)
#     287
#     288     def update_state(self, data):
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/base_preprocessing_layer.py in adapt(self, data, batch_size, steps)
#     256             with data_handler.catch_stop_iteration():
#     257                 for _ in data_handler.steps():
# --> 258                     self._adapt_function(iterator)
#     259                     if data_handler.should_sync:
#     260                         context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Type mismatch between parsed tensor (float) and dtype (uint8)
# 	 [[{{node ParseTensor_1}}]]
# 	 [[IteratorGetNext]] [Op:__inference_adapt_step_628]
